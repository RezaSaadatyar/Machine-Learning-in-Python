# %% [markdown]
# **Presented by: Reza Saadatyar (2024-2025)**<br/>
# **E-mail: Reza.Saadatyar@outlook.com**
#
# - Series
# - DataFrame
# - Missing data
# - Get_dummies: Convert categorical variable into dummy/indicator variables
# - Groupby

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %% [markdown]
# **Series**

# %%
series = pd.Series([7, 15, 4, 4, 7, 4], index=[
                   'r1', 'r2', 'r3', 'r4', 'r5', 'r6'])
series
# Out:
# r1     7
# r2    15
# r3     4
# r4     4
# r5     7
# r6     4
# dtype: int64

# %%
print(f"{series.r2=}")
print(f"\n {series[1]=}")
print(f"\n {series.values=}")
print(f"\n {series.index=}")
print(f"\n {series.value_counts=}")
# Out:
# series.r2=15
#
#  series[1]=15
#
#  series.values=array([ 7, 15,  4,  4,  7,  4], dtype=int64)
#
#  series.index=Index(['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], dtype='object')
#
#  series.value_counts=<bound method IndexOpsMixin.value_counts of r1     7
# r2    15
# r3     4
# r4     4
# r5     7
# r6     4
# dtype: int64>
# C:\Users\RezaS\AppData\Local\Temp\ipykernel_15340\4021472979.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"\n {series[1]=}")

# %% [markdown]
# **DataFrame**

# %%
df = pd.DataFrame([[1, 8], [3, 4], [5, 9], [7, 2]], index=[
                  'A1', 'A2', 'A3', 'A4'], columns=['B1', 'B2'])
df
# Out:
#     B1  B2
# A1   1   8
# A2   3   4
# A3   5   9
# A4   7   2

# %%
pd.crosstab(df['B1'], df['B2'])
# Out:
# B2  2  4  8  9
# B1
# 1   0  0  1  0
# 3   0  1  0  0
# 5   0  0  0  1
# 7   1  0  0  0

# %%
print(f"df[:3]:\n {df[:3]}")
print(f"\n df['B2']:\n{df['B2']}")
# Out:
# df[:3]:
#      B1  B2
# A1   1   8
# A2   3   4
# A3   5   9
#
#  df['B2']:
# A1    8
# A2    4
# A3    9
# A4    2
# Name: B2, dtype: int64

# %%
df.values
# Out:
# array([[1, 8],
#        [3, 4],
#        [5, 9],
#        [7, 2]], dtype=int64)

# %%
df[df < 5]
# Out:
#      B1   B2
# A1  1.0  NaN
# A2  3.0  4.0
# A3  NaN  NaN
# A4  NaN  2.0

# %%
df.head()
# Out:
#     B1  B2
# A1   1   8
# A2   3   4
# A3   5   9
# A4   7   2

# %%
df.tail(2)
# Out:
#     B1  B2
# A3   5   9
# A4   7   2

# %%
df.index
# Out:
# Index(['A1', 'A2', 'A3', 'A4'], dtype='object')

# %%
df.columns
# Out:
# Index(['B1', 'B2'], dtype='object')

# %%
df.T
# Out:
#     A1  A2  A3  A4
# B1   1   3   5   7
# B2   8   4   9   2

# %%
df.drop('A3', axis=0)
# Out:
#     B1  B2
# A1   1   8
# A2   3   4
# A4   7   2

# %%
df.drop('B2', axis=1)
# Out:
#     B1
# A1   1
# A2   3
# A3   5
# A4   7

# %%
df.describe()
# Out:
#              B1        B2
# count  4.000000  4.000000
# mean   4.000000  5.750000
# std    2.581989  3.304038
# min    1.000000  2.000000
# 25%    2.500000  3.500000
# 50%    4.000000  6.000000
# 75%    5.500000  8.250000
# max    7.000000  9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A1 to A4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   B1      4 non-null      int64
#  1   B2      4 non-null      int64
# dtypes: int64(2)
# memory usage: 268.0+ bytes

# %%
df = pd.DataFrame({'x': [1, 5],  'b': [-1, 4], 'c': [5, 6]})
df
# Out:
#    x  b  c
# 0  1 -1  5
# 1  5  4  6

# %%
df.sort_index(axis=1)
# Out:
#    b  c  x
# 0 -1  5  1
# 1  4  6  5

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#    x  c  b
# 0  1  5 -1
# 1  5  6  4

# %%
df.sort_values(by='x',ascending=False)
# Out:
#    x  b  c
# 1  5  4  6
# 0  1 -1  5

# %%
df[df.x < 5]
# Out:
#    x  b  c
# 0  1 -1  5

# %%
df.iloc[1][1], df.iloc[1]['b']
# Out:
# (4, 4)

# %%
np.random.seed(1)
pd.DataFrame(np.random.randn(6,4))
# Out:
#           0         1         2         3
# 0  1.624345 -0.611756 -0.528172 -1.072969
# 1  0.865408 -2.301539  1.744812 -0.761207
# 2  0.319039 -0.249370  1.462108 -2.060141
# 3 -0.322417 -0.384054  1.133769 -1.099891
# 4 -0.172428 -0.877858  0.042214  0.582815
# 5 -1.100619  1.144724  0.901591  0.502494

# %% [markdown]
# **Missing data**

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0], 
                   [3, 4, np.nan, 1], 
                   [np.nan, np.nan, np.nan, 5], 
                   [np.nan, 3, np.nan, 4],
                   [np.nan, np.nan, np.nan, np.nan]],
                    columns=list('ABCD'))
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  5.0
# 3  NaN  3.0 NaN  4.0
# 4  NaN  NaN NaN  NaN

# %%
df.isnull().sum()
# Out:
# A    4
# B    2
# C    5
# D    1
# dtype: int64

# %%
df.isna()
# Out:
#        A      B     C      D
# 0   True  False  True  False
# 1  False  False  True  False
# 2   True   True  True  False
# 3   True  False  True  False
# 4   True   True  True   True

# %%
df.notna()
# Out:
#        A      B      C      D
# 0  False   True  False   True
# 1   True   True  False   True
# 2  False  False  False   True
# 3  False   True  False   True
# 4  False  False  False  False

# %%
pd.isna(df['A'])
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: A, dtype: bool

# %%
df.fillna(0)
# Out:
#      A    B    C    D
# 0  0.0  2.0  0.0  0.0
# 1  3.0  4.0  0.0  1.0
# 2  0.0  0.0  0.0  5.0
# 3  0.0  3.0  0.0  4.0
# 4  0.0  0.0  0.0  0.0

# %%
df.fillna(df.mean())
# Out:
#      A    B   C    D
# 0  3.0  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  3.0  3.0 NaN  5.0
# 3  3.0  3.0 NaN  4.0
# 4  3.0  3.0 NaN  2.5

# %%
df.fillna(df.mean()['A':'B'])
# Out:
#      A    B   C    D
# 0  3.0  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  3.0  3.0 NaN  5.0
# 3  3.0  3.0 NaN  4.0
# 4  3.0  3.0 NaN  NaN

# %%
df.fillna(method='ffill')
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  3.0  4.0 NaN  5.0
# 3  3.0  3.0 NaN  4.0
# 4  3.0  3.0 NaN  4.0

# %%
df.fillna(value={'A': 0, 'B': 1, 'C': 2, 'D': 3}, limit=2)
# Out:
#      A    B    C    D
# 0  0.0  2.0  2.0  0.0
# 1  3.0  4.0  2.0  1.0
# 2  0.0  1.0  NaN  5.0
# 3  NaN  3.0  NaN  4.0
# 4  NaN  1.0  NaN  3.0

# %%
df.fillna(value={'A': 0, 'B': 1, 'C': 2, 'D': 3})
# Out:
#      A    B    C    D
# 0  0.0  2.0  2.0  0.0
# 1  3.0  4.0  2.0  1.0
# 2  0.0  1.0  2.0  5.0
# 3  0.0  3.0  2.0  4.0
# 4  0.0  1.0  2.0  3.0

# %%
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df['A'].dropna()
# Out:
# 1    3.0
# Name: A, dtype: float64

# %%
print(f"{df = }")
df.dropna(thresh=2)  # drop rows that have not at least 2 non-NaN values
# Out:
# df =      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  5.0
# 3  NaN  3.0 NaN  4.0
# 4  NaN  NaN NaN  NaN
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 3  NaN  3.0 NaN  4.0

# %%
print(f"{df = }")
df.dropna(how='all')  #only drop rows where all columns are NaN
# Out:
# df =      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  5.0
# 3  NaN  3.0 NaN  4.0
# 4  NaN  NaN NaN  NaN
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  5.0
# 3  NaN  3.0 NaN  4.0

# %%
df.dropna(subset=['B'])  # only drop rows where NaN appear in specific columns B
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 3  NaN  3.0 NaN  4.0

# %%
imputer = SimpleImputer(strategy='mean')     # Create a SimpleImputer with strategy='mean'
imputed_data = imputer.fit_transform(df)     # Fit the imputer on the data and transform it
df_imputed = pd.DataFrame(imputed_data, columns=df.columns) # Create a new DataFrame with imputed values
df_imputed
# Out:
#      A      B     C      D
# 0  1.0   6.00  11.0  16.00
# 1  2.0   8.25  12.0  17.00
# 2  3.0   8.00  13.0  18.00
# 3  4.0   9.00  14.0  17.75
# 4  5.0  10.00  15.0  20.00

# %% [markdown]
# **Get_dummies**

# %%
df = pd.read_csv("C:/Users/Reza/Documents/Pandas/Code/train_Titanic.csv")
df.head(5)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
pd.crosstab(df['Sex'], df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
df = df.drop(['PassengerId','Name','Ticket'], axis=1)        # Drop unnecessary columns
df.head(5)
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0       3    male  22.0      1      0   7.2500   NaN        S         0
# 1       1  female  38.0      1      0  71.2833   C85        C         1
# 2       3  female  26.0      0      0   7.9250   NaN        S         1
# 3       1  female  35.0      1      0  53.1000  C123        S         1
# 4       3    male  35.0      0      0   8.0500   NaN        S         0

# %%
edt  = pd.get_dummies(df['Embarked'], dtype=int)      # Convert categorical variable into dummy/indicator variables
edt
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
df = df.join(edt)
df.head(5)
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived  C  Q  \
# 0       3    male  22.0      1      0   7.2500   NaN        S         0  0  0
# 1       1  female  38.0      1      0  71.2833   C85        C         1  1  0
# 2       3  female  26.0      0      0   7.9250   NaN        S         1  0  0
# 3       1  female  35.0      1      0  53.1000  C123        S         1  0  0
# 4       3    male  35.0      0      0   8.0500   NaN        S         0  0  0
#
#    S
# 0  1
# 1  0
# 2  1
# 3  1
# 4  1

# %%
df.drop(['Embarked'], axis=1,inplace=True)
df.head(5)
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Cabin  Survived  C  Q  S
# 0       3    male  22.0      1      0   7.2500   NaN         0  0  0  1
# 1       1  female  38.0      1      0  71.2833   C85         1  1  0  0
# 2       3  female  26.0      0      0   7.9250   NaN         1  0  0  1
# 3       1  female  35.0      1      0  53.1000  C123         1  0  0  1
# 4       3    male  35.0      0      0   8.0500   NaN         0  0  0  1

# %% [markdown]
# **Groupby**

# %%
df = pd.DataFrame({'Bird' : ['A', 'A', 'B', 'B', 'B'],'Speed' : [380, 370, 24, 26,np.nan]})
df
# Out:
#   Bird  Speed
# 0    A  380.0
# 1    A  370.0
# 2    B   24.0
# 3    B   26.0
# 4    B    NaN

# %%
df.groupby(['Bird']).mean()
# Out:
#       Speed
# Bird
# A     375.0
# B      25.0

# %%
df['Speed'] = df.groupby(['Bird'])['Speed'].transform(lambda x: x.fillna(x.mean()))
df    # 4 --> B ---> df.groupby(['Bird']).mean()
# Out:
#   Bird  Speed
# 0    A  380.0
# 1    A  370.0
# 2    B   24.0
# 3    B   26.0
# 4    B   25.0

# %%
a = {"a":1, "b":2}
print(f"{a.keys() = }")
print(f"{a.values() = }")
print(f"{a.get("a") = }, {a.get("c") = }")
a["c"] = 5
print(f"{a = }")
print(f"{a.items() = }")
# Out:
# a.keys() = dict_keys(['a', 'b'])
# a.values() = dict_values([1, 2])
# a.get("a") = 1, a.get("c") = None
# a = {'a': 1, 'b': 2, 'c': 5}
# a.items() = dict_items([('a', 1), ('b', 2), ('c', 5)])
